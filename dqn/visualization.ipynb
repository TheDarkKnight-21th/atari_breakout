# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
score = pd.read_csv("score_record.csv")
loss = pd.read_csv("loss.csv")

# %%
score
# Out:
#      eval_score     step  Unnamed: 2
# 0           0.4        0        0.05
# 1           1.3    25000        0.05
# 2           0.0    50000        0.05
# 3           6.4    75000        0.05
# 4           1.6   100000        0.05
# ..          ...      ...         ...
# 395       391.2  9875000        0.05
# 396       315.6  9900000        0.05
# 397       219.3  9925000        0.05
# 398       381.9  9950000        0.05
# 399       306.5  9975000        0.05
#
# [400 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
plt.title("Average score")
plt.style.use('ggplot')
plt.plot(score.step , score.eval_score , color = "blue")
plt.xlabel("step")
plt.ylabel("score")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("loss")
plt.style.use('ggplot')
plt.plot(loss.step , loss.loss , color = "orange")
plt.xlabel("step")
plt.ylabel("loss")
plt.show()
